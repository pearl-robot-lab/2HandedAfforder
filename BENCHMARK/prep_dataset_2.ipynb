# %%
import os
import cv2
import torch
import h5py
import numpy as np
import json
from tqdm import trange

# %%
repo_path = "/home/sjauhri/IAS_WS/EgoVis/2handedafforder_repo/"
dataset_folder = repo_path + "BENCHMARK/dataset_bench/EPIC_DATA/datasets/dset/P01_01/"
out_folder = repo_path + "BENCHMARK/dataset_bench/bench_frames/P01_01/"
visualization_active = True

# %%
# loop through all the subdirectories in the data_folder provided
for subdir, dirs, files in os.walk(dataset_folder, topdown=True):

    print(f"Finding correct frame_ids...")

    # remove all dirs with 'cj' in the name
    dirs = [d for d in dirs if 'cj' not in d]
    
    # Get all consecutive frame_id 'sets'
    frame_ids = sorted([int(d) for d in dirs if d.isdigit()])
    consecutive_sets = []
    current_set = [frame_ids[0]]

    for j in range(1, len(frame_ids)):
        if frame_ids[j] == frame_ids[j - 1] + 1:
            current_set.append(frame_ids[j])
        else:
            consecutive_sets.append(current_set)
            current_set = [frame_ids[j]]

    consecutive_sets.append(current_set)
    print(consecutive_sets)

    break
# Out:
# Finding correct frame_ids...
# [[289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307], [776, 777, 778, 779, 780, 781, 782, 783, 784, 785, 786, 787, 788, 789, 790, 791, 792, 793, 794], [804, 805], [956, 957, 958, 959, 960, 961, 962, 963, 964, 965, 966, 967, 968, 969, 970, 971, 972, 973, 974], [1008, 1009, 1010, 1011], [1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023, 1024, 1025, 1026], [1049, 1050, 1051, 1052, 1053, 1054], [1056, 1057], [1112, 1113, 1114, 1115], [1118], [1120, 1121, 1122, 1123], [1206, 1207, 1208, 1209], [1214, 1215], [1217, 1218, 1219, 1220, 1221, 1222, 1223, 1224], [1393, 1394], [1506, 1507, 1508, 1509, 1510, 1511, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1523, 1524], [1591, 1592, 1593, 1594], [1596, 1597, 1598, 1599, 1600, 1601], [1603, 1604, 1605, 1606], [1609], [1781, 1782, 1783, 1784], [1791, 1792, 1793, 1794, 1795, 1796, 1797, 1798, 1799], [1837, 1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855], [2207, 2208, 2209, 2210, 2211], [2213, 2214], [2217], [2221, 2222, 2223, 2224, 2225], [2239, 2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2256, 2257], [2628, 2629], [2632], [2634, 2635, 2636, 2637], [2640, 2641, 2642, 2643, 2644, 2645, 2646], [2742], [3128, 3129, 3130, 3131, 3132], [3154, 3155, 3156], [3160, 3161, 3162, 3163, 3164, 3165, 3166, 3167], [3169], [3222, 3223], [3232], [3320], [3322], [3456, 3457, 3458, 3459, 3460, 3461, 3462], [3464, 3465, 3466, 3467, 3468, 3469, 3470], [3573, 3574, 3575, 3576, 3577, 3578, 3579, 3580, 3581, 3582, 3583, 3584, 3585, 3586, 3587, 3588, 3589, 3590], [3673, 3674, 3675, 3676, 3677], [3679, 3680, 3681, 3682], [4017, 4018], [4027], [4033, 4034], [4275, 4276, 4277, 4278, 4279, 4280, 4281, 4282, 4283, 4284, 4285, 4286, 4287, 4288, 4289, 4290, 4291, 4292, 4293], [4534], [4684, 4685], [4694], [4811], [4814], [4816], [4890], [4898], [4900], [4902, 4903], [4906, 4907], [5130, 5131, 5132, 5133], [5136, 5137, 5138, 5139, 5140, 5141, 5142], [5144, 5145], [5148], [5164, 5165], [5168, 5169, 5170, 5171, 5172, 5173, 5174, 5175, 5176, 5177], [5247, 5248, 5249, 5250, 5251, 5252, 5253, 5254, 5255, 5256, 5257, 5258, 5259, 5260], [5278], [5610, 5611, 5612], [5615, 5616, 5617, 5618, 5619, 5620, 5621, 5622, 5623, 5624], [5879, 5880, 5881, 5882, 5883, 5884, 5885, 5886, 5887, 5888], [5890, 5891, 5892, 5893, 5894, 5895, 5896], [6063], [6067, 6068, 6069, 6070, 6071], [6107, 6108, 6109, 6110, 6111, 6112, 6113, 6114, 6115, 6116, 6117], [6185, 6186, 6187, 6188, 6189, 6190, 6191, 6192, 6193, 6194, 6195, 6196, 6197, 6198, 6199, 6200, 6201, 6202, 6203], [6251], [6261], [6291], [6522, 6523, 6524, 6525, 6526, 6527, 6528, 6529, 6530, 6531, 6532], [6535, 6536, 6537, 6538, 6539, 6540], [6803], [6806, 6807, 6808, 6809, 6810, 6811, 6812, 6813, 6814, 6815, 6816, 6817, 6818, 6819, 6820, 6821], [7084, 7085, 7086, 7087, 7088, 7089, 7090, 7091, 7092, 7093, 7094, 7095, 7096, 7097, 7098, 7099, 7100, 7101, 7102], [7430, 7431, 7432], [7537, 7538, 7539, 7540, 7541, 7542, 7543, 7544, 7545, 7546], [7855, 7856, 7857], [7861, 7862, 7863], [7865, 7866, 7867, 7868, 7869, 7870, 7871, 7872, 7873], [8453, 8454, 8455, 8456, 8457], [8465], [9275, 9276, 9277, 9278, 9279, 9280, 9281], [9284, 9285, 9286, 9287, 9288, 9289, 9290], [9687, 9688], [10161, 10162, 10163, 10164, 10165, 10166, 10167, 10168, 10169, 10170, 10171, 10172, 10173, 10174, 10175, 10176, 10177, 10178, 10179], [10510], [10514, 10515, 10516, 10517, 10518, 10519, 10520, 10521, 10522, 10523, 10524, 10525, 10526, 10527, 10528], [11065, 11066, 11067, 11068, 11069], [11072, 11073, 11074], [11081], [11464], [14467, 14468, 14469, 14470, 14471, 14472, 14473, 14474, 14475, 14476, 14477, 14478, 14479, 14480, 14481, 14482, 14483, 14484, 14485], [14802], [14810], [14816, 14817, 14818], [15135], [15139, 15140, 15141, 15142], [15370, 15371, 15372, 15373, 15374, 15375, 15376, 15377, 15378, 15379, 15380, 15381, 15382, 15383, 15384, 15 ...

# %%
frame_file_prefix = "frame_000"
# if out_folder does not exist, create it
if not os.path.exists(out_folder):
    os.makedirs(out_folder)

for subdir, dirs, files in os.walk(dataset_folder, topdown=True):
    print(f"Copying to bench_frames subfolders...")
    for i in trange(len(consecutive_sets)):
        consecutive_set = consecutive_sets[i]
    
        # pick one random frame from the set
        rand_idx = np.random.randint(0, len(consecutive_set))
        frame_id = consecutive_set[rand_idx]
        frame_id_string = str(frame_id).zfill(7)
        # print("Frame ID: ", frame_id)
        bechmark_frame_file_path = subdir + frame_id_string + "/" + "benchmark_frame.png"
        # copy benchmark frame to out_folder
        cmd = f"cp {bechmark_frame_file_path} {out_folder}/benchmark_frame_000{frame_id}.png"
        # print(cmd)
        os.system(cmd)

        # if possible, pick one more frame from the consecutive set:
        if len(consecutive_set) > 1:
            new_rand_idx = np.random.randint(0, len(consecutive_set))
            while new_rand_idx == rand_idx:
                new_rand_idx = np.random.randint(0, len(consecutive_set))
            rand_idx = new_rand_idx
            frame_id = consecutive_set[rand_idx]
            frame_id_string = str(frame_id).zfill(7)
            bechmark_frame_file_path = subdir + frame_id_string + "/" + "benchmark_frame.png"
            # copy benchmark frame to out_folder
            cmd = f"cp {bechmark_frame_file_path} {out_folder}/benchmark_frame_000{frame_id}.png"
            # print(cmd)
            os.system(cmd)

        # print(f"Copied {original_frame_file_path} to {subdir + dir}/")

    break
# Out:
# Copying to bench_frames subfolders...
# 100%|██████████| 671/671 [00:02<00:00, 226.41it/s]

# %%
# frame_file_prefix = "frame_000"
# # if out_folder does not exist, create it
# if not os.path.exists(out_folder):
#     os.makedirs(out_folder)

# # loop through all the subdirectories in the data_folder provided
# for subdir, dirs, files in os.walk(dataset_folder, topdown=True):

#     print(f"Copying to bench_frames subfolders...")
#     # for dir in dirs:
#     for i in trange(len(dirs)):
#         dir = dirs[i]
#         if 'cj' in dir:
#             # skip
#             continue
    
#         frame_id = dir
#         # print("Frame ID: ", frame_id)
#         bechmark_frame_file_path = subdir + dir + "/" + "benchmark_frame.png"
#         # copy benchmark frame to out_folder
#         cmd = f"cp {bechmark_frame_file_path} {out_folder}/benchmark_frame_000{frame_id}.png"
#         # print(cmd)
#         os.system(cmd)

#         # print(f"Copied {original_frame_file_path} to {subdir + dir}/")

#     break
