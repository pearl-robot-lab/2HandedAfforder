# %%
import os
import cv2
import torch
import h5py
import numpy as np
import json
from tqdm import trange

# %%
repo_path = "/home/sjauhri/IAS_WS/EgoVis/2handedafforder_repo/"
dataset_folder = repo_path + "BENCHMARK/dataset_bench/EPIC_DATA/datasets/dset/P20_03/"
out_folder = repo_path + "BENCHMARK/dataset_bench/bench_frames/P20_03/"
visualization_active = True

# %%
# loop through all the subdirectories in the data_folder provided
for subdir, dirs, files in os.walk(dataset_folder, topdown=True):

    print(f"Finding correct frame_ids...")

    # remove all dirs with 'cj' in the name
    dirs = [d for d in dirs if 'cj' not in d]
    
    # Get all consecutive frame_id 'sets'
    frame_ids = sorted([int(d) for d in dirs if d.isdigit()])
    consecutive_sets = []
    current_set = [frame_ids[0]]

    for j in range(1, len(frame_ids)):
        if frame_ids[j] == frame_ids[j - 1] + 1:
            current_set.append(frame_ids[j])
        else:
            consecutive_sets.append(current_set)
            current_set = [frame_ids[j]]

    consecutive_sets.append(current_set)
    print(consecutive_sets)

    break
# Out:
# Finding correct frame_ids...
# [[169, 170, 171, 172, 173, 174], [176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187], [232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250], [302], [346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364], [451, 452, 453], [489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507], [574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585, 586, 587, 588, 589, 590, 591, 592], [623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634, 635, 636, 637], [639, 640, 641], [707, 708, 709, 710, 711, 712, 713], [717, 718, 719, 720, 721, 722, 723, 724, 725], [849], [852, 853, 854], [1282, 1283, 1284, 1285, 1286, 1287], [1289], [1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966], [1968, 1969, 1970, 1971, 1972, 1973, 1974], [1976, 1977], [2044], [2301, 2302, 2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319], [2414, 2415], [2419, 2420, 2421, 2422], [2424, 2425, 2426, 2427], [2524], [2526], [2530, 2531, 2532], [2534, 2535], [2537, 2538, 2539, 2540], [2558, 2559, 2560, 2561, 2562, 2563, 2564, 2565, 2566, 2567, 2568, 2569, 2570, 2571, 2572, 2573, 2574, 2575, 2576], [2642], [2645, 2646, 2647, 2648, 2649, 2650, 2651, 2652, 2653, 2654], [2665, 2666, 2667, 2668, 2669, 2670, 2671, 2672, 2673, 2674, 2675, 2676, 2677, 2678, 2679, 2680, 2681, 2682, 2683], [2755, 2756, 2757, 2758, 2759, 2760, 2761, 2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771, 2772, 2773], [3265, 3266, 3267, 3268, 3269, 3270, 3271, 3272, 3273, 3274, 3275, 3276, 3277, 3278, 3279, 3280, 3281, 3282, 3283], [3506, 3507, 3508, 3509, 3510, 3511, 3512, 3513, 3514, 3515, 3516, 3517, 3518, 3519, 3520, 3521, 3522, 3523, 3524], [3709, 3710, 3711, 3712, 3713, 3714, 3715, 3716, 3717, 3718, 3719, 3720, 3721, 3722, 3723, 3724, 3725, 3726, 3727], [3747], [3754, 3755, 3756, 3757], [3759], [3762, 3763, 3764], [3798, 3799, 3800, 3801], [3803, 3804, 3805, 3806, 3807, 3808, 3809, 3810], [3848], [3851], [3853, 3854, 3855, 3856, 3857, 3858, 3859, 3860, 3861, 3862, 3863, 3864], [3972], [3974], [4026], [4031], [4033], [4035], [4041], [4183, 4184, 4185, 4186, 4187, 4188, 4189, 4190, 4191, 4192, 4193, 4194, 4195, 4196, 4197, 4198, 4199, 4200, 4201], [4243, 4244, 4245, 4246, 4247, 4248, 4249, 4250, 4251, 4252, 4253, 4254, 4255, 4256, 4257, 4258], [4260, 4261], [4364, 4365, 4366, 4367, 4368, 4369, 4370, 4371, 4372, 4373, 4374, 4375, 4376, 4377, 4378, 4379, 4380, 4381, 4382], [4436, 4437, 4438, 4439, 4440, 4441, 4442, 4443, 4444, 4445, 4446, 4447, 4448, 4449, 4450, 4451, 4452, 4453, 4454], [4733, 4734, 4735, 4736, 4737, 4738, 4739, 4740, 4741, 4742, 4743, 4744, 4745, 4746, 4747, 4748, 4749, 4750, 4751], [5292, 5293, 5294, 5295, 5296, 5297, 5298, 5299, 5300, 5301, 5302, 5303, 5304, 5305, 5306, 5307, 5308, 5309, 5310], [5342, 5343, 5344, 5345, 5346, 5347, 5348, 5349, 5350, 5351, 5352, 5353, 5354, 5355, 5356, 5357, 5358, 5359, 5360], [5494, 5495, 5496, 5497, 5498, 5499, 5500, 5501, 5502, 5503, 5504, 5505, 5506, 5507, 5508, 5509, 5510, 5511, 5512], [5601, 5602, 5603, 5604, 5605, 5606, 5607, 5608, 5609, 5610, 5611, 5612, 5613], [5615, 5616, 5617], [5648], [5654], [5656], [5660, 5661, 5662, 5663], [5868, 5869, 5870, 5871, 5872, 5873, 5874, 5875, 5876, 5877, 5878, 5879, 5880, 5881, 5882, 5883, 5884, 5885, 5886], [5937, 5938], [5940, 5941, 5942, 5943, 5944, 5945, 5946, 5947, 5948, 5949, 5950, 5951, 5952, 5953, 5954, 5955], [6208, 6209, 6210, 6211, 6212, 6213, 6214, 6215, 6216, 6217, 6218, 6219], [6222, 6223, 6224, 6225, 6226], [6269, 6270, 6271, 6272, 6273, 6274, 6275, 6276, 6277, 6278, 6279, 6280, 6281, 6282, 6283], [6321, 6322, 6323, 6324, 6325, 6326, 6327, 6328, 6329, 6330, 6331, 6332, 6333, 6334, 6335, 6336, 6337, 6338, 6339], [6366, 6367, 6368, 6369, 6370, 6371, 6372, 6373, 6374, 6375, 6376, 6377, 6378, 6379, 6380, 6381, 6382, 6383, 6384], [6405, 6406, 6407, 6408, 6409, 6410, 6411, 6412, 6413, 6414, 6415, 6416, 6417, 6418, 6419 ...

# %%
frame_file_prefix = "frame_000"
# if out_folder does not exist, create it
if not os.path.exists(out_folder):
    os.makedirs(out_folder)

for subdir, dirs, files in os.walk(dataset_folder, topdown=True):
    print(f"Copying to bench_frames subfolders...")
    for i in trange(len(consecutive_sets)):
        consecutive_set = consecutive_sets[i]
    
        # pick one random frame from the set
        rand_idx = np.random.randint(0, len(consecutive_set))
        frame_id = consecutive_set[rand_idx]
        frame_id_string = str(frame_id).zfill(7)
        # print("Frame ID: ", frame_id)
        bechmark_frame_file_path = subdir + frame_id_string + "/" + "benchmark_frame.png"
        # copy benchmark frame to out_folder
        cmd = f"cp {bechmark_frame_file_path} {out_folder}/benchmark_frame_000{frame_id}.png"
        # print(cmd)
        os.system(cmd)

        # if possible, pick one more frame from the consecutive set:
        if len(consecutive_set) > 1:
            new_rand_idx = np.random.randint(0, len(consecutive_set))
            while new_rand_idx == rand_idx:
                new_rand_idx = np.random.randint(0, len(consecutive_set))
            rand_idx = new_rand_idx
            frame_id = consecutive_set[rand_idx]
            frame_id_string = str(frame_id).zfill(7)
            bechmark_frame_file_path = subdir + frame_id_string + "/" + "benchmark_frame.png"
            # copy benchmark frame to out_folder
            cmd = f"cp {bechmark_frame_file_path} {out_folder}/benchmark_frame_000{frame_id}.png"
            # print(cmd)
            os.system(cmd)

        # print(f"Copied {original_frame_file_path} to {subdir + dir}/")

    break
# Out:
# Copying to bench_frames subfolders...
# 100%|██████████| 123/123 [00:00<00:00, 174.33it/s]

# %%
# frame_file_prefix = "frame_000"
# # if out_folder does not exist, create it
# if not os.path.exists(out_folder):
#     os.makedirs(out_folder)

# # loop through all the subdirectories in the data_folder provided
# for subdir, dirs, files in os.walk(dataset_folder, topdown=True):

#     print(f"Copying to bench_frames subfolders...")
#     # for dir in dirs:
#     for i in trange(len(dirs)):
#         dir = dirs[i]
#         if 'cj' in dir:
#             # skip
#             continue
    
#         frame_id = dir
#         # print("Frame ID: ", frame_id)
#         bechmark_frame_file_path = subdir + dir + "/" + "benchmark_frame.png"
#         # copy benchmark frame to out_folder
#         cmd = f"cp {bechmark_frame_file_path} {out_folder}/benchmark_frame_000{frame_id}.png"
#         # print(cmd)
#         os.system(cmd)

#         # print(f"Copied {original_frame_file_path} to {subdir + dir}/")

#     break
